# %% [markdown]
# <a href="https://colab.research.google.com/github/anvithashetty17/Form-handling/blob/main/WholesaleCustomer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# Load the dataset
wholesale_customers = fetch_ucirepo(id=292)

# Features and target
X = wholesale_customers.data.features
y = wholesale_customers.data.targets

print(X.head())
print(y.head())
# Out:
#    Channel  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2  12669  9656     7561     214              2674        1338
# 1        2   7057  9810     9568    1762              3293        1776
# 2        2   6353  8808     7684    2405              3516        7844
# 3        1  13265  1196     4221    6404               507        1788
# 4        2  22615  5410     7198    3915              1777        5185
#    Region
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

display(df)
# Out:
#      Channel  Region   Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3   12669   9656     7561     214              2674
# 1          2       3    7057   9810     9568    1762              3293
# 2          2       3    6353   8808     7684    2405              3516
# 3          1       3   13265   1196     4221    6404               507
# 4          2       3   22615   5410     7198    3915              1777
# 5          2       3    9413   8259     5126     666              1795
# 6          2       3   12126   3199     6975     480              3140
# 7          2       3    7579   4956     9426    1669              3321
# 8          1       3    5963   3648     6192     425              1716
# 9          2       3    6006  11093    18881    1159              7425
# 10         2       3    3366   5403    12974    4400              5977
# 11         2       3   13146   1124     4523    1420               549
# ...

# %%
# Display first 5 rows
print(df.head())
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
print(df.shape)
# Out:
# (440, 8)

# %%
print("Columns:")
print(df.columns)
# Out:
# Columns:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicassen'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
print(dir(df))
# Out:
# ['Channel', 'Delicassen', 'Detergents_Paper', 'Fresh', 'Frozen', 'Grocery', 'Milk', 'Region', 'T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__arrow_c_stream__', '__bool__', '__class__', '__contains__', '__copy__', '__dataframe__', '__dataframe_consortium_standard__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__
# ...

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
X = df.drop('Region', axis=1)

# %%
wcss = []

for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_scaled)

# %%
df['Cluster'] = clusters
print(df.head())
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656     7561     214              2674
# 1        2       3   7057  9810     9568    1762              3293
# 2        2       3   6353  8808     7684    2405              3516
# 3        1       3  13265  1196     4221    6404               507
# 4        2       3  22615  5410     7198    3915              1777
#
#    Delicassen  Cluster
# 0        1338        2
# 1        1776        2
# 2        7844        2
# 3        1788        0
# 4        5185        2

# %%
print("Cluster Centers:")
print(kmeans.cluster_centers_)
# Out:
# Cluster Centers:
# [[-6.90297086e-01 -1.97762666e-01 -3.91053342e-01 -4.63965439e-01
#   -1.33122907e-01 -4.40719149e-01 -1.93935481e-01]
#  [ 1.44865163e+00  3.88728973e-01  3.94304862e+00  4.02164626e+00
#    3.57841274e-02  4.22611641e+00  9.41635735e-01]
#  [ 1.44865163e+00 -3.22859683e-01  4.05520838e-01  6.34573509e-01
#   -3.36079123e-01  6.61855289e-01  1.67238515e-03]
#  [-6.01174223e-01  1.77176025e+00 -5.63924381e-02 -2.27707982e-01
#    1.44737148e+00 -4.31067593e-01  4.50533906e-01]
#  [-6.90297086e-01  1.96681731e+00  5.17550306e+00  1.28721685e+00
#    6.90059988e+00 -5.54861977e-01  1.64784475e+01]]

# %%
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 0    251
# 2    129
# 3     48
# 1     11
# 4      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:,0], X_scaled[:,1], c=clusters, cmap='viridis')
plt.xlabel("Channel")
plt.ylabel("Fresh")
plt.title("K-Means Clustering")
plt.show()

# %%
# !pip install scikit-learn-extra
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.0/819.0 kB 32.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-learn-extra: filename=scikit_learn_extra-0.3.0-cp312-cp312-linux_x86_64.whl size=1988969 sha256=0130307a369de33a37e27368a7389c5204eb93b32b1c67ec700990eba2fc5274
#   Stored in directory: /root/.cache/pip/wheels/17/4d/c3/c6d5d563c1bf8146d059d63be3678abc2f2801fba0aaf5f0b8
# Successfully built scikit-learn-extra
# ...

# %%
# !pip install numpy==1.26.
# !pip install scikit-learn-extra

# %%
from ucimlrepo import fetch_ucirepo
import pandas as pd

# Load dataset
wholesale_customers = fetch_ucirepo(id=292)

# Combine features and target into one DataFrame
X = wholesale_customers.data.features
y = wholesale_customers.data.targets

df = pd.concat([X, y], axis=1)

print(df.head())
# Out:
#    Channel  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  Region
# 0        2  12669  9656     7561     214              2674        1338       3
# 1        2   7057  9810     9568    1762              3293        1776       3
# 2        2   6353  8808     7684    2405              3516        7844       3
# 3        1  13265  1196     4221    6404               507        1788       3
# 4        2  22615  5410     7198    3915              1777        5185       3

# %%
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import StandardScaler

X = df.drop('Region', axis=1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

kmedoids = KMedoids(
    n_clusters=5,
    metric='manhattan',
    random_state=42
)

clusters = kmedoids.fit_predict(X_scaled)

df['Cluster'] = clusters

print(df.head())
# Out:
#    Channel  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen  \
# 0        2  12669  9656     7561     214              2674        1338
# 1        2   7057  9810     9568    1762              3293        1776
# 2        2   6353  8808     7684    2405              3516        7844
# 3        1  13265  1196     4221    6404               507        1788
# 4        2  22615  5410     7198    3915              1777        5185
#
#    Region  Cluster
# 0       3        2
# 1       3        2
# 2       3        2
# 3       3        4
# 4       3        0
